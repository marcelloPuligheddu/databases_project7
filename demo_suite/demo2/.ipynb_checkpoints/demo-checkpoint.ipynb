# %%
import pandas as pd
import numpy as np
import sqlalchemy as sqlA
import sqlite3
import os
import matplotlib.pyplot as plt

# %%
if os.path.exists('../DB_uni_large/uni_large.db'):
    os.remove('../DB_uni_large/uni_large.db')
# engine = sqlA.create_engine('sqlite:///DB_uni_large/uni_large.db')
conn = sqlite3.connect('../DB_uni_large/uni_large.db')
c = conn.cursor()
conn.commit()
conn

# %%
with conn as con:
    for inputfilename in ['../DB_uni_large/uni_definition.sql', '../DB_uni_large/uni_relation_large.sql']:
        with open(inputfilename) as file:
                instructions = file.read().replace('\n','').replace('\t',' ').split(';')
                print('Reading', inputfilename, 'Instructions:', len(instructions), flush=True)
                for i, instr in enumerate(instructions):
                    instr = instr+';'
                    con.execute(instr)
# Out:
# Reading ../DB_uni_large/uni_definition.sql Instructions: 12
# Reading ../DB_uni_large/uni_relation_large.sql Instructions: 34632

# %%
with conn as con:
    out = con.execute("""
select distinct student.name, student.dept_name, course.dept_name
from student, takes, course 
where 
    student.ID = takes.ID and
    takes.course_id = course.course_id and
    course.dept_name = 'Comp. Sci.'
; """
                     )
    print((out.fetchall()))
# Out:
# [('Manber', 'Civil Eng.', 'Comp. Sci.'), ('Duan', 'Civil Eng.', 'Comp. Sci.'), ('Colin', 'Civil Eng.', 'Comp. Sci.'), ('Mediratta', 'Geology', 'Comp. Sci.'), ('Grosch', 'Astronomy', 'Comp. Sci.'), ('Kieras', 'Physics', 'Comp. Sci.'), ('Reed', 'English', 'Comp. Sci.'), ('Okaf', 'Geology', 'Comp. Sci.'), ('Zabary', 'Statistics', 'Comp. Sci.'), ('Shabuno', 'Math', 'Comp. Sci.'), ('Terauchi', 'Physics', 'Comp. Sci.'), ('Veselovsky', 'Elec. Eng.', 'Comp. Sci.'), ('Dhav', 'Biology', 'Comp. Sci.'), ('Xue', 'Languages', 'Comp. Sci.'), ('Roses', 'Accounting', 'Comp. Sci.'), ('Tzeng', 'Civil Eng.', 'Comp. Sci.'), ('Al-Tahat', 'English', 'Comp. Sci.'), ('Rokhs', 'Physics', 'Comp. Sci.'), ('Foels', 'Marketing', 'Comp. Sci.'), ('Jr', 'Accounting', 'Comp. Sci.'), ('Saito', 'Physics', 'Comp. Sci.'), ('Betho', 'Languages', 'Comp. Sci.'), ('Yamashita', 'Astronomy', 'Comp. Sci.'), ('Rakoj', 'Mech. Eng.', 'Comp. Sci.'), ('Kwan', 'Languages', 'Comp. Sci.'), ('Neff', 'Pol. Sci.', 'Comp. Sci.'), ('Juol', 'Athletics', 'Comp. Sci.'), ('Mendelzon', 'Languages', 'Comp. Sci.'), ('Skeen', 'History', 'Comp. Sci.'), ('Marcus', 'Marketing', 'Comp. Sci.'), ('Zhanr', 'Civil Eng.', 'Comp. Sci.'), ('Stone', 'Marketing', 'Comp. Sci.'), ('Tewari', 'Geology', 'Comp. Sci.'), ('Sin', 'Accounting', 'Comp. Sci.'), ('Alqui', 'Languages', 'Comp. Sci.'), ('Diab', 'Civil Eng.', 'Comp. Sci.'), ('Bonatto', 'Biology', 'Comp. Sci.'), ('Wolter', 'Mech. Eng.', 'Comp. Sci.'), ('Srini', 'Pol. Sci.', 'Comp. Sci.'), ('Ignj', 'Math', 'Comp. Sci.'), ('Bedny', 'Astronomy', 'Comp. Sci.'), ('Sommerfeldt', 'Pol. Sci.', 'Comp. Sci.'), ('Lazos', 'Physics', 'Comp. Sci.'), ('Berger', 'Math', 'Comp. Sci.'), ('Oswald', 'Comp. Sci.', 'Comp. Sci.'), ('Starker', 'History', 'Comp. Sci.'), ('Miao', 'Comp. Sci.', 'Comp. Sci.'), ('Takeshi', 'Athletics', 'Comp. Sci.'), ('Whitley', 'Geology', 'Comp. Sci.'), ('Ramadan', 'Psychology', 'Comp. Sci.'), ('Haigh', 'Comp. Sci.', 'Comp. Sci.'), ('Martinsen', 'History', 'Comp. Sci.'), ('Azevedo', 'Astronomy', 'Comp. Sci.'), ('Lehtinen', 'Psychology', 'Comp. Sci.'), ('Malinen', 'Athletics', 'Comp. Sci.'), ('Singhal', 'Comp. Sci.', 'Comp. Sci.'), ('Massour', 'Mech. Eng.', 'Comp. Sci.'), ('She', 'Statistics', 'Comp. Sci.'), ('Sasso', 'Psychology', 'Comp. Sci.'), ('Arinb', 'Physics', 'Comp. Sci.'), ('Anis', 'Geology', 'Comp. Sci.'), ('Yeung', 'Athletics', 'Comp. Sci.'), ('Umehara', 'Marketing', 'Comp. Sci.'), ('Neuhold', 'Finance', 'Comp. Sci.'), ('Marques', 'Math', 'Comp. Sci.'), ('Wolter', 'Pol. Sci.', 'Comp. Sci.'), ('Orlet', 'Cybernetics', 'Comp. Sci.'), ('Uhrig', 'English', 'Comp. Sci.'), ('Bandekar', 'Finance', 'Comp. Sci.'), ('Liao', 'Accounting', 'Comp. Sci.'), ('Morimoto', 'Mech. Eng.', 'Comp. Sci.'), ('Rahman', 'Languages', 'Comp. Sci.'), ('Kanata', 'Astronomy', 'Comp. Sci.'), ('Angs', 'Accounting', 'Comp. Sci.'), ('Toffoli', 'History', 'Comp. Sci.'), ('Kuwadak', 'Comp. Sci.', 'Comp. Sci.'), ('Kantors', 'Geology', 'Comp. Sci.'), ('Biehl', 'Math', 'Comp. Sci.'), ('Akaiw', 'Accounting', 'Comp. Sci.'), ('Swartj', 'Geology', 'Comp. Sci.'), ('Chuon', 'Civil Eng.', 'Comp. Sci.'), ('Holn', 'Astronomy', 'Comp. Sci.'), ('Matsunami', 'Biology', 'Comp. Sci.'), ('Ratcliff', 'Mech. Eng.', 'Comp. Sci.'), ('Caleff', 'Languages', 'Comp. Sci.'), ('Zouao', 'English', 'Comp. Sci.'), ('Mathur', 'Mech. Eng.', 'Comp. Sci.'), ('Peter', 'Languages', 'Comp. Sci.'), ('Ould', 'Athletics', 'Comp. Sci.'), ('Pearlman', 'Biology', 'Comp. Sci.'), ('Srivastava', 'Languages', 'Comp. Sci.'), ('Audeh', 'Biology', 'Comp. Sci.'), ('Tavan', 'Psychology', 'Comp. Sci.'), ('Karpist', 'Finance', 'Comp. Sci.'), ('Ishikawa', 'Languages', 'Comp. Sci.'), ('Chanon', 'Biology', 'Comp. Sci.'), ('Brailsford', 'Cybernetics', 'Comp. Sci.'), ('Chyr', 'Marketing', 'Comp. Sci.'), ('Nirenbu', 'Pol. Sci.', 'Comp. Sci.'), ('Westbrook', 'Civil Eng.', 'Comp. Sci.'), ('Kangs', 'Physics', 'Comp. Sci.'), ('Marinov', 'Elec. Eng.', 'Comp. Sci.'), ('Goodwin', 'Civil Eng.', 'Comp. Sci.'), ('Peter', 'Biology', 'Comp. Sci.') ...

# %%
with conn as con:
    out = con.execute("""
; """
                     )
    print((out.fetchall()))
# Out:
# []

# %%
with conn as con:
    out = con.execute("""
select title from course where course.dept_name = 'Comp. Sci.' and course.credits = 3
; """)
    for x in out.fetchall():
        print(x)
# Out:
# ('International Finance',)
# ('Japanese',)
# ('Computability Theory',)

# %%
with conn as con:
    out = con.execute("""
select student.ID, student.name, teaches.course_id, instructor.name
from instructor, teaches, student, takes
where 
    student.ID = takes.ID and
    takes.course_id = teaches.course_id and
    instructor.ID = teaches.ID and
    instructor.name = 'Luo'
    
; """)
    print([description[0] for description in out.description])
    for x in out.fetchall():
        print(x)
# Out:
# ['ID', 'name', 'course_id', 'name']
# ('10033', 'Zelty', '679', 'Luo')
# ('10454', 'Ugarte', '679', 'Luo')
# ('10527', 'Kieras', '679', 'Luo')
# ('107', 'Shabuno', '679', 'Luo')
# ('1087', 'Roses', '679', 'Luo')
# ('11095', 'Schultz', '679', 'Luo')
# ('11966', 'Kowe', '679', 'Luo')
# ('12078', 'Knutson', '679', 'Luo')
# ('12236', 'Bricker', '679', 'Luo')
# ('1232', 'Marcus', '679', 'Luo')
# ('13028', 'Okano', '679', 'Luo')
# ('13365', 'Wolter', '679', 'Luo')
# ('13506', 'Patrick', '679', 'Luo')
# ('1367', 'Ignj', '679', 'Luo')
# ('13757', 'Bedny', '679', 'Luo')
# ('14032', 'Belhadji', '679', 'Luo')
# ('14094', 'Miao', '679', 'Luo')
# ('14182', 'Moszkowski', '679', 'Luo')
# ('14284', 'Takeshi', '679', 'Luo')
# ('14874', 'Singhal', '679', 'Luo')
# ('15249', 'Cheah', '679', 'Luo')
# ('15340', 'Silbert', '679', 'Luo')
# ('15613', 'Umehara', '679', 'Luo')
# ('15726', 'Neuhold', '679', 'Luo')
# ('16035', 'Starker', '679', 'Luo')
# ('163', 'Bandekar', '679', 'Luo')
# ('16515', 'Suppan', '679', 'Luo')
# ('16528', 'Angs', '679', 'Luo')
# ('16885', 'Biehl', '679', 'Luo')
# ('17057', 'Swartj', '679', 'Luo')
# ('17133', 'Kang', '679', 'Luo')
# ('17339', 'Petzo', '679', 'Luo')
# ('1737', 'Shinagawa', '679', 'Luo')
# ('17665', 'Tewari', '679', 'Luo')
# ('17924', 'Tavan', '679', 'Luo')
# ('1836', 'Marinov', '679', 'Luo')
# ('19048', 'Leuen', '679', 'Luo')
# ('19220', 'Hayashi', '679', 'Luo')
# ('19342', 'Bouzeghoub', '679', 'Luo')
# ('1954', 'Frank', '679', 'Luo')
# ('19791', 'Vanrell', '679', 'Luo')
# ('19824', 'Savelieva', '679', 'Luo')
# ('20002', 'Fournier', '679', 'Luo')
# ('20985', 'Wunderli', '679', 'Luo')
# ('21009', 'Geon', '679', 'Luo')
# ('2133', 'Nardi', '679', 'Luo')
# ('21394', 'Patel', '679', 'Luo')
# ('21401', 'Garze', '679', 'Luo')
# ('21774', 'Moh', '679', 'Luo')
# ('2201', 'Sauer', '679', 'Luo')
# ('22142', 'Gerstend', '679', 'Luo')
# ('22260', 'Daat', '679', 'Luo')
# ('22620', 'Lykin', '679', 'Luo')
# ('23110', 'Sahani', '679', 'Luo')
# ('23270', 'Bouras', '679', 'Luo')
# ('23439', 'Cai', '679', 'Luo')
# ('23794', 'Sokolov', '679', 'Luo')
# ('24746', 'Schrefl', '679', 'Luo')
# ('25611', 'Sve', '679', 'Luo')
# ('25940', 'Rosenkrantz', '679', 'Luo')
# ('26028', 'Birchler', '679', 'Luo')
# ('26080', 'Simmel', '679', 'Luo')
# ('26881', 'Markin', '679', 'Luo')
# ('27044', 'Kota', '679', 'Luo')
# ('27528', 'Probst', '679', 'Luo')
# ('27687', 'Yüksel', '679', 'Luo')
# ('28409', 'Hirasawa', '679', 'Luo')
# ('288', 'Canellas', '679', 'Luo')
# ('28952', 'Kennedy', '679', 'Luo')
# ('28977', 'Chatterton', '679', 'Luo')
# ('29091', 'Ahso', '679', 'Luo')
# ('29260', 'Verhoeven', '679', 'Luo')
# ('29645', 'Oller', '679', 'Luo')
# ('29920', 'Kogure', '679', 'Luo')
# ('30021', 'Youseffi', '679', 'Luo')
# ('30188', 'Ahmad', '679', 'Luo')
# ('30650', 'Chaudhuri', '679', 'Luo')
# ('31341', 'Rotter', '679', 'Luo')
# ('3143', 'Haddad', '679', 'Luo')
# ('31486', 'Okubo', '679', 'Luo')
# ('31560', 'Neld', '679', 'Luo')
# ('31761', 'Jame', '679', 'Luo')
# ('32065', 'Tapia', '679', 'Luo')
# ('32376', 'Nakajima', '679', 'Luo')
# ('32483', 'Atre', '679', 'Luo')
# ('33107', 'Liley', '679', 'Luo')
# ('3335', 'Otterm', '679', 'Luo')
# ('336', 'Constantinescu', '679', 'Luo')
# ('34055', 'Orono', '679', 'Luo')
# ('34126', 'Schreitm', '679', 'Luo')
# ('34197', 'Nestor', '679', 'Luo')
# ('34322', 'Baba', '679', 'Luo')
# ('34392', 'Lauciu', '679', 'Luo')
# ('34542', 'Basile', '679', 'Luo')
# ('34569', 'Arndt', '679', 'Luo')
# ('35198', 'Loc', '679', 'Luo')
# ('35498', 'Lanfr', '679', 'Luo')
# ('35588', 'John', '679', 'Luo')
# ('36265', 'Kaupp', '679', 'Luo')
# ('36379', 'Triebel', '679', 'Luo')
# ('3651', 'Narayanan', '679', 'Luo')
# ('36845', 'Okaf', '679', 'Luo')
# ('36995', 'Sgot', '679', 'Luo')
# ('37430', 'Norman', '679', 'Luo')
# ('37581', 'Arndt', '679', 'Luo')
# ('38013', 'Frolova', '679', 'Luo')
# ('38895', 'Beuthel', '679', 'Luo')
# ('38899', 'Murphy', '679', 'Luo')
# ('39204', 'Castle', '679', 'Luo')
# ('39521', 'Holloway', '679', 'Luo')
# ('39552', 'Tsukamoto', '679', 'Luo')
# ('39876', 'Wood', '679', 'Luo')
# ('39927', 'Bartels', '679', 'Luo')
# ('40116', 'Joshi', '679', 'Luo')
# ('40897', 'Coppens', '679', 'Luo')
# ('41741', 'Kato', '679', 'Luo')
# ('4182', 'Powals', '679', 'Luo')
# ('41890', 'Srivastava', '679', 'Luo')
# ('42688', 'Palma', '679', 'Luo')
# ('42991', 'Kaiser', '679', 'Luo')
# ('435', 'Moskow', '679', 'Luo')
# ('43616', 'Tam', '679', 'Luo')
# ('43912', 'Papakir', '679', 'Luo')
# ('4508', 'Cochran', '679', 'Luo')
# ('46155', 'Kruglyak', '679', 'Luo')
# ('4645', 'Ryoo', '679', 'Luo')
# ('46725', 'Richi', '679', 'Luo')
# ('47379', 'Wakamiya', '679', 'Luo')
# ('47487', 'Villa', '679', 'Luo')
# ('48247', 'Gustafsson', '679', 'Luo')
# ('48469', 'Kolodko', '679', 'Luo')
# ('48471', 'Elias', '679', 'Luo')
# ('48589', 'Martyno', '679', 'Luo')
# ('48640', 'Brown', '679', 'Luo')
# ('48660', 'Emam', '679', 'Luo')
# ('48901', 'Gong', '679', 'Luo')
# ('49280', 'Wilson', '679', 'Luo')
# ('4940', 'Rhyne', '679', 'Luo')
# ('49611', 'Karande', '679', 'Luo')
# ('49813', 'Al-Hu', '679', 'Luo')
# ('50013', 'Milanic', '679', 'Luo')
# ('50267', 'Spengler', '679', 'Luo')
# ('50414', 'Landau', '679', 'Luo')
# ('50658', 'Cayto', '679', 'Luo')
# ('50664', 'Rajnov', '679', 'Luo')
# ('50719', 'Model', '679', 'Luo')
# ('50873', 'Beck', '679', 'Luo')
# ('50944', 'Tao', '679', 'Luo')
# ('50966', 'Concilio', '679', 'Luo')
# ('51084', 'Pah', '679', 'Luo')
# ('51817', 'MacIntyre', '679', 'Luo')
# ('51868', 'Guthk', '679', 'Luo')
# ('52120', 'Redw', '679', 'Luo')
# ('52291', 'Wolff', '679', 'Luo')
# ('52471', 'Recc', '679', 'Luo')
# ('52494', 'Sznajder', '679', 'Luo')
# ('52669', 'Rayad', '679', 'Luo')
# ('52707', 'Arena', '679', 'Luo')
# ('53152', 'Sayre', '679', 'Luo')
# ('53424', 'Lemoine', '679', 'Luo')
# ('5399', 'Chun', '679', 'Luo')
# ('544', 'Uchiyama', '679', 'Luo')
# ('54622', 'Yu', '679', 'Luo')
# ('56003', 'Someren', '679', 'Luo')
# ('56057', 'Hull', '679', 'Luo')
# ('56058', 'Fettes', '679', 'Luo')
# ('56078', 'Soltys', '679', 'Luo')
# ('56089', 'Mezzar', '679', 'Luo')
# ('56212', 'Rolland', '679', 'Luo')
# ('57242', 'Chatfield', '679', 'Luo')
# ('57334', 'Roeder', '679', 'Luo')
# ('57377', 'Soricu', '679', 'Luo')
# ('57474', 'Coddington', '679', 'Luo')
# ('57538', 'Albuquerque', '679', 'Luo')
# ('57787', 'Alexandri', '679', 'Luo')
# ('57941', 'Kleinberg', '679', 'Luo')
# ('58355', 'Honeyman', '679', 'Luo')
# ('58634', 'Choung', '679', 'Luo')
# ('5943', 'Rubio', '679', 'Luo')
# ('59553', 'Schoenfl', '679', 'Luo')
# ('61081', 'Bai', '679', 'Luo')
# ('62487', 'Durrant', '679', 'Luo')
# ('62520', 'Im', '679', 'Luo')
# ('62636', 'Soni', '679', 'Luo')
# ('62795', 'Conradie', '679', 'Luo')
# ('62832', 'Anderson', '679', 'Luo')
# ('63040', 'Hochri', '679', 'Luo')
# ('63645', 'Mandviwall', '679', 'Luo')
# ('64067', 'Mennif', '679', 'Luo')
# ('64164', 'Zander', '679', 'Luo')
# ('64192', 'Pradhan', '679', 'Luo')
# ('645', 'Kane', '679', 'Luo')
# ('64820', 'Hendrickson', '679', 'Luo')
# ('65038', 'Papakir', '679', 'Luo')
# ('65396', 'Rossos', '679', 'Luo')
# ('65753', 'Planti', '679', 'Luo')
# ('66356', 'Xi', '679', 'Luo')
# ('6673', 'Bernhart', '679', 'Luo')
# ('66753', 'Mazzat', '679', 'Luo')
# ('67017', 'Westervelt', '679', 'Luo')
# ('67024', 'Aufr', '679', 'Luo')
# ('6712', 'Westphal', '679', 'Luo')
# ('67340', 'Dubu', '679', 'Luo')
# ('67407', 'Yoneda', '679', 'Luo')
# ('67425', 'Cooper', '679', 'Luo')
# ('67514', 'Psil', '679', 'Luo')
# ('67657', 'Beeu', '679', 'Luo')
# ('67660', 'Newitt', '679', 'Luo')
# ('68278', 'Becker', '679', 'Luo')
# ('69132', 'Sciore', '679', 'Luo')
# ('69230', 'Masum', '679', 'Luo')
# ('69581', 'Prabhakaran', '679', 'Luo')
# ('69679', 'Ramírez', '679', 'Luo')
# ('69850', 'Alexandri', '679', 'Luo')
# ('70098', 'Prabhakaran', '679', 'Luo')
# ('7043', 'Gryts', '679', 'Luo')
# ('70452', 'Al-Hu', '679', 'Luo')
# ('71085', 'Giannoulis', '679', 'Luo')
# ('71387', 'Tleu', '679', 'Luo')
# ('71529', 'Fredrickso', '679', 'Luo')
# ('72501', 'Mulet', '679', 'Luo')
# ('72657', 'Hird', '679', 'Luo')
# ('73206', 'Maw', '679', 'Luo')
# ('73213', 'Fall', '679', 'Luo')
# ('7390', 'Stone', '679', 'Luo')
# ('74473', 'Ledermann', '679', 'Luo')
# ('74672', 'Eggers', '679', 'Luo')
# ('7498', 'Charng', '679', 'Luo')
# ('75299', 'Miao', '679', 'Luo')
# ('75534', 'Simmel', '679', 'Luo')
# ('75794', 'Hons', '679', 'Luo')
# ('76250', 'Maw', '679', 'Luo')
# ('76743', 'Rani', '679', 'Luo')
# ('76799', 'Monger', '679', 'Luo')
# ('77003', 'Munro', '679', 'Luo')
# ('77415', 'Morales', '679', 'Luo')
# ('78434', 'Ruhe', '679', 'Luo')
# ('78787', 'Rissanen', '679', 'Luo')
# ('78922', 'Koltso', '679', 'Luo')
# ('7970', 'Bartels', '679', 'Luo')
# ('8022', 'Heng', '679', 'Luo')
# ('80990', 'Strzem', '679', 'Luo')
# ('81207', 'Masri', '679', 'Luo')
# ('81550', 'Harada', '679', 'Luo')
# ('81789', 'Urwin', '679', 'Luo')
# ('81884', 'Kereth', '679', 'Luo')
# ('82083', 'Peeri', '679', 'Luo')
# ('82688', 'Rote', '679', 'Luo')
# ('83170', 'Ariav', '679', 'Luo')
# ('83204', 'Tauber', '679', 'Luo')
# ('83398', 'Quinta', '679', 'Luo')
# ('8378', 'Stenv', '679', 'Luo')
# ('84167', 'Sakanushi', '679', 'Luo')
# ('84702', 'Lucas', '679', 'Luo')
# ('84704', 'Rammer', '679', 'Luo')
# ('84845', 'Zuo', '679', 'Luo')
# ('84865', 'Fernandez-Gonzalez', '679', 'Luo')
# ('85063', 'Chaney', '679', 'Luo')
# ('85366', 'Erol', '679', 'Luo')
# ('85505', 'Wells', '679', 'Luo')
# ('85754', 'Betho', '679', 'Luo')
# ('85981', 'Kahs', '679', 'Luo')
# ('8603', 'Piedrah', '679', 'Luo')
# ('86375', 'Loher', '679', 'Luo')
# ('86753', 'Leister', '679', 'Luo')
# ('87246', 'Dellwo', '679', 'Luo')
# ('87268', 'Koenig', '679', 'Luo')
# ('8860', 'Aminian', '679', 'Luo')
# ('89132', 'Janssen', '679', 'Luo')
# ('90082', 'Esparza', '679', 'Luo')
# ('90181', 'Giannoulis', '679', 'Luo')
# ('90220', 'Iacovoni', '679', 'Luo')
# ('90609', 'Mohamed', '679', 'Luo')
# ('90914', 'Grange', '679', 'Luo')
# ('9183', 'Sutter', '679', 'Luo')
# ('91851', 'Tchuri', '679', 'Luo')
# ('92040', 'Alexandri', '679', 'Luo')
# ('92693', 'Mattor', '679', 'Luo')
# ('92776', 'Oki', '679', 'Luo')
# ('92864', 'Rogers', '679', 'Luo')
# ('92867', 'Khene', '679', 'Luo')
# ('93043', 'McQuillan', '679', 'Luo')
# ('93508', 'Graham', '679', 'Luo')
# ('94257', 'Unger', '679', 'Luo')
# ('94535', 'Nishida', '679', 'Luo')
# ('94730', 'Neff', '679', 'Luo')
# ('94801', 'Chakraborty', '679', 'Luo')
# ('94894', 'Kozlov', '679', 'Luo')
# ('95201', 'Yang', '679', 'Luo')
# ('95366', 'Isogai', '679', 'Luo')
# ('95850', 'Schrefl', '679', 'Luo')
# ('9605', 'Beeu', '679', 'Luo')
# ('96134', 'Prince', '679', 'Luo')
# ('96178', 'Hay', '679', 'Luo')
# ('96895', 'Stelzl', '679', 'Luo')
# ('97042', 'Bhargava', '679', 'Luo')
# ('97101', 'Marek', '679', 'Luo')
# ('97355', 'Ratcliff', '679', 'Luo')
# ('97551', 'Labaye', '679', 'Luo')
# ('97590', 'Rammer', '679', 'Luo')
# ('97868', 'Schinag', '679', 'Luo')
# ('98047', 'Takahashi', '679', 'Luo')
# ('98940', 'Hawthorne', '679', 'Luo')
# ('99189', 'Shelest', '679', 'Luo')
# ('99463', 'Jacobi', '679', 'Luo')
# ('99760', 'Sakamoto', '679', 'Luo')
# ('99977', 'Englund', '679', 'Luo')

# %%
with conn as con:
    out = con.execute("""
select max(salary)
from instructor
; """)
    print([description[0] for description in out.description])
    for x in out.fetchall():
        print(x)
# Out:
# ['max(salary)']
# (124651.41,)

# %%
with conn as con:
    out = con.execute("""
select *
from instructor, teaches
where
    instructor.ID = teaches.ID
    and salary = (select max(salary) from instructor)

; """)
    print([description[0] for description in out.description])
    for x in out.fetchall():
        print(x)

print()

with conn as con:
    out = con.execute("""
select *
from instructor, advisor, student
where instructor.ID = advisor.i_ID
and student.ID = advisor.s_ID
and salary = (select max(salary) from instructor)

; """)
    print([description[0] for description in out.description])
    for x in out.fetchall():
        print(x)
# Out:
# ['ID', 'name', 'dept_name', 'salary', 'ID', 'course_id', 'sec_id', 'semester', 'year']
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '19368', '545', '1', 'Fall', 2001)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '19368', '581', '1', 'Spring', 2005)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '19368', '591', '1', 'Spring', 2005)
#
# ['ID', 'name', 'dept_name', 'salary', 's_ID', 'i_ID', 'ID', 'name', 'dept_name', 'tot_cred']
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '24746', '19368', '24746', 'Schrefl', 'History', 4)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '39046', '19368', '39046', 'Narasimhamu', 'Math', 121)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '59046', '19368', '59046', 'Reichl', 'Elec. Eng.', 56)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '92040', '19368', '92040', 'Alexandri', 'Athletics', 66)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '10481', '19368', '10481', 'Grosch', 'Astronomy', 39)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '24387', '19368', '24387', 'Yap', 'History', 29)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '80976', '19368', '80976', 'Mozayani', 'Elec. Eng.', 34)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '16631', '19368', '16631', 'Stratulat', 'Biology', 20)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '50873', '19368', '50873', 'Beck', 'Marketing', 33)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '30188', '19368', '30188', 'Ahmad', 'Marketing', 126)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '7390', '19368', '7390', 'Stone', 'Accounting', 30)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '98843', '19368', '98843', 'Julier', 'Cybernetics', 85)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '61332', '19368', '61332', 'Canon', 'Astronomy', 8)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '22086', '19368', '22086', 'Ockerb', 'Athletics', 23)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '76768', '19368', '76768', 'Oblak', 'Pol. Sci.', 56)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '31035', '19368', '31035', 'Arnoux', 'Civil Eng.', 92)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '85754', '19368', '85754', 'Betho', 'Finance', 45)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '81175', '19368', '81175', 'Zelek', 'Biology', 0)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '24002', '19368', '24002', 'Russa', 'Languages', 14)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '92659', '19368', '92659', 'Mathias', 'Biology', 98)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '72006', '19368', '72006', 'Jawad', 'Comp. Sci.', 114)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '56849', '19368', '56849', 'Osaka', 'Accounting', 27)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '51416', '19368', '51416', 'Shan', 'Psychology', 51)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '66279', '19368', '66279', 'Reynolds', 'Math', 91)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '11377', '19368', '11377', 'Jr', 'Accounting', 100)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '62373', '19368', '62373', 'Cheed', 'Accounting', 60)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '58170', '19368', '58170', 'Lao', 'Statistics', 119)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '463', '19368', '463', 'Houtsm', 'Physics', 78)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '81245', '19368', '81245', 'Mandviwall', 'Languages', 35)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '22912', '19368', '22912', 'Sendlm', 'Geology', 63)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '71085', '19368', '71085', 'Giannoulis', 'Elec. Eng.', 10)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '87439', '19368', '87439', 'Scheffer', 'Comp. Sci.', 93)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '70918', '19368', '70918', 'Holland', 'English', 23)

# %%
with conn as con:
    out = con.execute("""
select instructor.name, count(*) as number_of_slave
from instructor, advisor, student
where instructor.ID = advisor.i_ID
and student.ID = advisor.s_ID
group by instructor.ID
; """)
    print([description[0] for description in out.description])
    for x in out.fetchall():
        print(x)

print()
with conn as con:
    out = con.execute("""
select avg(number_of_slave), min(number_of_slave), max(number_of_slave), count(number_of_slave), sum(number_of_slave)
from (
    select count(*) as number_of_slave
    from instructor, advisor, student
    where instructor.ID = advisor.i_ID
    and student.ID = advisor.s_ID
    group by instructor.ID
)
; """)
    print([description[0] for description in out.description])
    for x in out.fetchall():
        print(x)
# Out:
# ['name', 'number_of_slave']
# ('Lembr', 39)
# ('Bawa', 38)
# ('Yazdi', 48)
# ('Wieland', 33)
# ('DAgostino', 40)
# ('Liley', 38)
# ('Kean', 37)
# ('Atanassov', 44)
# ('Moreira', 35)
# ('Gustafsson', 38)
# ('Bourrier', 32)
# ('Bondi', 33)
# ('Soisalon-Soininen', 54)
# ('Morris', 42)
# ('Arias', 50)
# ('Murata', 45)
# ('Tung', 41)
# ('Luo', 44)
# ('Vicentino', 41)
# ('Romero', 34)
# ('Lent', 36)
# ('Sarkar', 49)
# ('Shuming', 39)
# ('Konstantinides', 28)
# ('Bancilhon', 48)
# ('Hau', 45)
# ('Dusserre', 40)
# ('Desyl', 31)
# ('Jaekel', 41)
# ('McKinnon', 31)
# ('Gutierrez', 36)
# ('Mingoz', 46)
# ('Pimenta', 38)
# ('Yin', 48)
# ('Sullivan', 46)
# ('Voronina', 31)
# ('Kenje', 39)
# ('Mahmoud', 54)
# ('Pingr', 33)
# ('Ullman ', 40)
# ('Levine', 46)
# ('Queiroz', 43)
# ('Valtchev', 40)
# ('Bietzk', 39)
# ('Choll', 24)
# ('Arinb', 41)
# ('Sakurai', 41)
# ('Mird', 38)
# ('Bertolino', 50)
# ('Dale', 33)
#
# ['avg(number_of_slave)', 'min(number_of_slave)', 'max(number_of_slave)', 'count(number_of_slave)', 'sum(number_of_slave)']
# (40.0, 24, 54, 50, 2000)

# %%
with conn as con:
    out = con.execute("""
select dept_name, avg(salary)
from instructor
group by dept_name
; """)
    print([description[0] for description in out.description])
    for x in out.fetchall():
        print(x)
# Out:
# ['dept_name', 'avg(salary)']
# ('Accounting', 48716.5925)
# ('Astronomy', 79070.08)
# ('Athletics', 77098.198)
# ('Biology', 61287.25)
# ('Comp. Sci.', 98133.47)
# ('Cybernetics', 96346.5675)
# ('Elec. Eng.', 74162.73999999999)
# ('English', 72089.04999999999)
# ('Finance', 105311.38)
# ('Geology', 99382.59)
# ('Languages', 57421.85666666667)
# ('Marketing', 84097.4375)
# ('Mech. Eng.', 79813.02)
# ('Physics', 114576.9)
# ('Pol. Sci.', 100053.07333333332)
# ('Psychology', 61143.05)
# ('Statistics', 67795.44166666667)

# %%
with conn as con:
    out = con.execute("""
select * 
from instructor natural join teaches
; """)
    print([description[0] for description in out.description])
    for x in out.fetchall():
        print(x)
# Out:
# ['ID', 'name', 'dept_name', 'salary', 'course_id', 'sec_id', 'semester', 'year']
# ('34175', 'Bondi', 'Comp. Sci.', 115469.11, '747', '1', 'Spring', 2004)
# ('3199', 'Gustafsson', 'Elec. Eng.', 82534.37, '169', '1', 'Spring', 2007)
# ('6569', 'Mingoz', 'Finance', 105311.38, '445', '1', 'Spring', 2001)
# ('28097', 'Kean', 'English', 35023.18, '808', '1', 'Fall', 2003)
# ('22591', 'DAgostino', 'Psychology', 59706.49, '962', '1', 'Spring', 2008)
# ('90376', 'Bietzk', 'Cybernetics', 117836.5, '158', '1', 'Fall', 2008)
# ('3199', 'Gustafsson', 'Elec. Eng.', 82534.37, '561', '1', 'Fall', 2006)
# ('34175', 'Bondi', 'Comp. Sci.', 115469.11, '274', '1', 'Fall', 2002)
# ('34175', 'Bondi', 'Comp. Sci.', 115469.11, '571', '1', 'Spring', 2004)
# ('79081', 'Ullman ', 'Accounting', 47307.1, '345', '1', 'Spring', 2008)
# ('80759', 'Queiroz', 'Biology', 45538.32, '559', '1', 'Fall', 2002)
# ('22591', 'DAgostino', 'Psychology', 59706.49, '991', '1', 'Spring', 2008)
# ('22591', 'DAgostino', 'Psychology', 59706.49, '400', '2', 'Fall', 2003)
# ('74420', 'Voronina', 'Physics', 121141.99, '376', '1', 'Fall', 2006)
# ('73623', 'Sullivan', 'Elec. Eng.', 90038.09, '694', '1', 'Fall', 2002)
# ('6569', 'Mingoz', 'Finance', 105311.38, '137', '1', 'Spring', 2002)
# ('95709', 'Sakurai', 'English', 118143.98, '270', '1', 'Spring', 2010)
# ('36897', 'Morris', 'Marketing', 43770.36, '795', '1', 'Spring', 2004)
# ('74420', 'Voronina', 'Physics', 121141.99, '443', '2', 'Spring', 2002)
# ('77346', 'Mahmoud', 'Geology', 99382.59, '486', '1', 'Fall', 2009)
# ('79081', 'Ullman ', 'Accounting', 47307.1, '408', '1', 'Spring', 2007)
# ('6569', 'Mingoz', 'Finance', 105311.38, '362', '3', 'Spring', 2008)
# ('6569', 'Mingoz', 'Finance', 105311.38, '527', '1', 'Fall', 2004)
# ('41930', 'Tung', 'Athletics', 50482.03, '401', '1', 'Fall', 2003)
# ('79081', 'Ullman ', 'Accounting', 47307.1, '408', '2', 'Spring', 2003)
# ('77346', 'Mahmoud', 'Geology', 99382.59, '493', '1', 'Spring', 2010)
# ('4233', 'Luo', 'English', 88791.45, '679', '1', 'Spring', 2010)
# ('99052', 'Dale', 'Cybernetics', 93348.83, '237', '2', 'Fall', 2009)
# ('95709', 'Sakurai', 'English', 118143.98, '258', '1', 'Fall', 2007)
# ('63287', 'Jaekel', 'Athletics', 103146.87, '334', '1', 'Fall', 2009)
# ('28097', 'Kean', 'English', 35023.18, '366', '1', 'Fall', 2005)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '581', '1', 'Spring', 2005)
# ('42782', 'Vicentino', 'Elec. Eng.', 34272.67, '793', '1', 'Spring', 2002)
# ('74420', 'Voronina', 'Physics', 121141.99, '959', '1', 'Fall', 2006)
# ('41930', 'Tung', 'Athletics', 50482.03, '421', '1', 'Fall', 2004)
# ('6569', 'Mingoz', 'Finance', 105311.38, '426', '1', 'Spring', 2006)
# ('6569', 'Mingoz', 'Finance', 105311.38, '362', '2', 'Fall', 2006)
# ('77346', 'Mahmoud', 'Geology', 99382.59, '864', '1', 'Spring', 2006)
# ('3335', 'Bourrier', 'Comp. Sci.', 80797.83, '960', '1', 'Fall', 2009)
# ('43779', 'Romero', 'Astronomy', 79070.08, '105', '1', 'Fall', 2009)
# ('48507', 'Lent', 'Mech. Eng.', 107978.47, '626', '1', 'Fall', 2006)
# ('99052', 'Dale', 'Cybernetics', 93348.83, '893', '1', 'Fall', 2007)
# ('22591', 'DAgostino', 'Psychology', 59706.49, '663', '1', 'Spring', 2005)
# ('25946', 'Liley', 'Languages', 90891.69, '192', '1', 'Fall', 2002)
# ('6569', 'Mingoz', 'Finance', 105311.38, '349', '1', 'Spring', 2008)
# ('99052', 'Dale', 'Cybernetics', 93348.83, '237', '1', 'Spring', 2008)
# ('22591', 'DAgostino', 'Psychology', 59706.49, '972', '1', 'Spring', 2009)
# ('77346', 'Mahmoud', 'Geology', 99382.59, '704', '1', 'Spring', 2008)
# ('36897', 'Morris', 'Marketing', 43770.36, '242', '1', 'Fall', 2009)
# ('99052', 'Dale', 'Cybernetics', 93348.83, '158', '2', 'Spring', 2008)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '545', '1', 'Fall', 2001)
# ('36897', 'Morris', 'Marketing', 43770.36, '791', '1', 'Spring', 2006)
# ('22591', 'DAgostino', 'Psychology', 59706.49, '642', '1', 'Fall', 2004)
# ('95709', 'Sakurai', 'English', 118143.98, '468', '1', 'Fall', 2005)
# ('3335', 'Bourrier', 'Comp. Sci.', 80797.83, '949', '1', 'Fall', 2007)
# ('99052', 'Dale', 'Cybernetics', 93348.83, '748', '1', 'Fall', 2003)
# ('43779', 'Romero', 'Astronomy', 79070.08, '489', '1', 'Fall', 2007)
# ('28400', 'Atanassov', 'Statistics', 84982.92, '603', '1', 'Fall', 2003)
# ('81991', 'Valtchev', 'Biology', 77036.18, '415', '1', 'Fall', 2010)
# ('48570', 'Sarkar', 'Pol. Sci.', 87549.8, '867', '2', 'Fall', 2010)
# ('3199', 'Gustafsson', 'Elec. Eng.', 82534.37, '631', '1', 'Spring', 2007)
# ('74420', 'Voronina', 'Physics', 121141.99, '443', '1', 'Spring', 2010)
# ('81991', 'Valtchev', 'Biology', 77036.18, '702', '1', 'Spring', 2001)
# ('14365', 'Lembr', 'Accounting', 32241.56, '843', '1', 'Fall', 2010)
# ('74420', 'Voronina', 'Physics', 121141.99, '612', '1', 'Fall', 2007)
# ('99052', 'Dale', 'Cybernetics', 93348.83, '629', '1', 'Spring', 2003)
# ('43779', 'Romero', 'Astronomy', 79070.08, '105', '2', 'Fall', 2002)
# ('79081', 'Ullman ', 'Accounting', 47307.1, '200', '2', 'Fall', 2002)
# ('99052', 'Dale', 'Cybernetics', 93348.83, '496', '1', 'Fall', 2001)
# ('50330', 'Shuming', 'Physics', 108011.81, '468', '2', 'Fall', 2007)
# ('36897', 'Morris', 'Marketing', 43770.36, '696', '1', 'Spring', 2002)
# ('77346', 'Mahmoud', 'Geology', 99382.59, '735', '1', 'Spring', 2003)
# ('14365', 'Lembr', 'Accounting', 32241.56, '200', '1', 'Spring', 2007)
# ('90643', 'Choll', 'Statistics', 57807.09, '461', '1', 'Fall', 2002)
# ('77346', 'Mahmoud', 'Geology', 99382.59, '735', '2', 'Spring', 2010)
# ('6569', 'Mingoz', 'Finance', 105311.38, '362', '1', 'Fall', 2005)
# ('43779', 'Romero', 'Astronomy', 79070.08, '476', '1', 'Fall', 2010)
# ('74420', 'Voronina', 'Physics', 121141.99, '239', '1', 'Fall', 2006)
# ('6569', 'Mingoz', 'Finance', 105311.38, '304', '1', 'Fall', 2009)
# ('22591', 'DAgostino', 'Psychology', 59706.49, '599', '1', 'Spring', 2003)
# ('63287', 'Jaekel', 'Athletics', 103146.87, '852', '1', 'Spring', 2008)
# ('79081', 'Ullman ', 'Accounting', 47307.1, '760', '1', 'Spring', 2004)
# ('19368', 'Wieland', 'Pol. Sci.', 124651.41, '591', '1', 'Spring', 2005)
# ('3199', 'Gustafsson', 'Elec. Eng.', 82534.37, '169', '2', 'Fall', 2002)
# ('36897', 'Morris', 'Marketing', 43770.36, '313', '1', 'Fall', 2010)
# ('41930', 'Tung', 'Athletics', 50482.03, '692', '1', 'Spring', 2010)
# ('22591', 'DAgostino', 'Psychology', 59706.49, '867', '1', 'Fall', 2006)
# ('22591', 'DAgostino', 'Psychology', 59706.49, '482', '1', 'Fall', 2005)
# ('15347', 'Bawa', 'Athletics', 72140.88, '457', '1', 'Spring', 2001)
# ('99052', 'Dale', 'Cybernetics', 93348.83, '802', '1', 'Spring', 2003)
# ('22591', 'DAgostino', 'Psychology', 59706.49, '338', '1', 'Spring', 2007)
# ('22591', 'DAgostino', 'Psychology', 59706.49, '352', '1', 'Spring', 2006)
# ('22591', 'DAgostino', 'Psychology', 59706.49, '338', '2', 'Spring', 2006)
# ('95709', 'Sakurai', 'English', 118143.98, '960', '2', 'Fall', 2006)
# ('65931', 'Pimenta', 'Cybernetics', 79866.95, '875', '1', 'Spring', 2005)
# ('22591', 'DAgostino', 'Psychology', 59706.49, '400', '1', 'Spring', 2007)
# ('99052', 'Dale', 'Cybernetics', 93348.83, '927', '1', 'Fall', 2002)
# ('79081', 'Ullman ', 'Accounting', 47307.1, '974', '1', 'Fall', 2003)
# ('28400', 'Atanassov', 'Statistics', 84982.92, '604', '1', 'Spring', 2009)
# ('6569', 'Mingoz', 'Finance', 105311.38, '319', '1', 'Spring', 2003)

# %%
out = None
with conn as con:
    out = con.execute("""
select dept_name, avg(salary) as average_salary
from instructor
group by dept_name
; """)
label = [description[0] for description in out.description]
res = np.array(out.fetchall()).T

plt.figure(figsize=(20, 10))
plt.bar(res[0], [float(x) for x in res[1]])
plt.xlabel(label[0])
plt.ylabel(label[1])
plt.show()
