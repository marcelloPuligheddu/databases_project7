# %%
import datetime, warnings, scipy 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading the DATA SET

# %% [markdown]
# In this notebook, I developed a model aimed at predicting flight delays at the Destination Airport. The purpose is to create a Data set which can be used for visualization and model Building so as to predict the Delays of Flights. I did the visualization so as to get better inferences about the data. For, model fitting I have seperated the Dataset into training Data and Testing Data so that prediction can be done on the testing Data. I also showed how to import Tableau and make visualization more crisp and clear.
#
# Technical aspect Covered:
#
# visualization: matplolib, seaborn, Tableau
#
# data manipulation: pandas, numpy
#
# modeling: sklearn
#
# class definition: regression, Boosting, Bagging
#
# For EDA I used some part of Python coding and Tableau Visulization so as to get a brief insight and inference from the data. Various Plots are created so as to get a great idea of whats happening in the Dataset and what is the most important variable affecting the dalays of the airlines. Feature scaling is a method used to normalize the range of independent variables or features of data and this concept is used.

# %%
data = pd.read_csv("../dot/red_flights.csv")

# %%
airport = pd.read_csv('../dot/airports.csv')
airlines = pd.read_csv('../dot/airlines.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19999 entries, 0 to 19998
# Data columns (total 31 columns):
# YEAR                   19999 non-null int64
# MONTH                  19999 non-null int64
# DAY                    19999 non-null int64
# DAY_OF_WEEK            19999 non-null int64
# AIRLINE                19999 non-null object
# FLIGHT_NUMBER          19999 non-null int64
# TAIL_NUMBER            19976 non-null object
# ORIGIN_AIRPORT         19999 non-null object
# DESTINATION_AIRPORT    19999 non-null object
# SCHEDULED_DEPARTURE    19999 non-null int64
# DEPARTURE_TIME         19590 non-null float64
# DEPARTURE_DELAY        19590 non-null float64
# TAXI_OUT               19589 non-null float64
# WHEELS_OFF             19589 non-null float64
# SCHEDULED_TIME         19999 non-null int64
# ELAPSED_TIME           19559 non-null float64
# AIR_TIME               19559 non-null float64
# DISTANCE               19999 non-null int64
# WHEELS_ON              19577 non-null float64
# TAXI_IN                19577 non-null float64
# SCHEDULED_ARRIVAL      19999 non-null int64
# ARRIVAL_TIME           19577 non-null float64
# ARRIVAL_DELAY          19559 non-null float64
# DIVERTED               19999 non-null int64
# CANCELLED              19999 non-null int64
# CANCELLATION_REASON    415 non-null object
# AIR_SYSTEM_DELAY       3333 non-null float64
# SECURITY_DELAY         3333 non-null float64
# AIRLINE_DELAY          3333 non-null float64
# LATE_AIRCRAFT_DELAY    3333 non-null float64
# WEATHER_DELAY          3333 non-null float64
# dtypes: float64(15), int64(11), object(5)
# memory usage: 4.7+ MB

# %%
data.shape
# Out:
# (19999, 31)

# %% [markdown]
# The Data Contains 31 columns and 1048575 Rows

# %%
data.describe()
# Out:
#           YEAR         MONTH           DAY  DAY_OF_WEEK  FLIGHT_NUMBER  \
# count  19999.0  19999.000000  19999.000000      19999.0   19999.000000
# mean    2015.0      6.500275     16.000750          4.0    2261.633632
# std        0.0      5.500138     15.000375          0.0    1834.103263
# min     2015.0      1.000000      1.000000          4.0       1.000000
# 25%     2015.0      1.000000      1.000000          4.0     734.000000
# 50%     2015.0     12.000000     31.000000          4.0    1705.000000
# 75%     2015.0     12.000000     31.000000          4.0    3454.000000
# max     2015.0     12.000000     31.000000          4.0    7438.000000
#
#        SCHEDULED_DEPARTURE  DEPARTURE_TIME  DEPARTURE_DELAY      TAXI_OUT  \
# count         19999.000000    19590.000000     19590.000000  19589.000000
# mean           1297.704385     1311.818275         7.981572     14.988361
# std             378.533588      383.513304        33.226612      6.922112
# min               5.000000        1.000000       -41.000000      3.000000
# 25%            1017.000000     1026.000000        -4.000000     11.000000
# 50%            1300.000000     1313.000000        -1.000000     13.000000
# 75%            1546.000000     1558.750000         9.000000     17.000000
# max            2359.000000     2400.000000      1649.000000    113.000000
#
#          WHEELS_OFF      ...        SCHEDULED_ARRIVAL  ARRIVAL_TIME  \
# count  19589.000000      ...             19999.000000  19577.000000
# mean    1332.571239      ...              1498.750288   1502.209327
# std      383.855795      ...               404.074918    409.048364
# min        1.000000      ...                 1.000000      1.000000
# 25%     1041.000000      ...              1225.000000   1230.000000
# 50%     1326.000000      ...              1513.000000   1520.000000
# 75%     1611.000000      ...              1800.000000   1805.000000
# max     2400.000000      ...              2359.000000   2400.000000
#
#        ARRIVAL_DELAY      DIVERTED     CANCELLED  AIR_SYSTEM_DELAY  \
# count   19559.000000  19999.000000  19999.000000       3333.000000
# mean        1.504678      0.001250      0.020751          7.588359
# std        34.859478      0.035335      0.142553         12.624330
# min       -76.000000      0.000000      0.000000          0.000000
# 25%       -14.000000      0.000000      0.000000          0.000000
# 50%        -5.000000      0.000000      0.000000          0.000000
# 75%         7.000000      0.000000      0.000000         14.000000
# max      1636.000000      1.000000      1.000000        164.000000
#
#        SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# count     3333.000000    3333.000000          3333.000000    3333.000000
# mean         0.113411      21.391539            18.277228       0.957996
# std          2.350649      54.261848            38.453554       9.223517
# min          0.000000       0.000000             0.000000       0.000000
# 25%          0.000000       0.000000             0.000000       0.000000
# 50%          0.000000       8.000000             1.000000       0.000000
# 75%          0.000000      22.000000            22.000000       0.000000
# max        107.000000    1636.000000           524.000000     213.000000
#
# [8 rows x 26 columns]

# %%
data.head()
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE      ...        \
# 0            ANC                 SEA                    5      ...
# 1            LAX                 PBI                   10      ...
# 2            SFO                 CLT                   20      ...
# 3            LAX                 MIA                   20      ...
# 4            SEA                 ANC                   25      ...
#
#    ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 0         408.0          -22.0         0          0                  NaN
# 1         741.0           -9.0         0          0                  NaN
# 2         811.0            5.0         0          0                  NaN
# 3         756.0           -9.0         0          0                  NaN
# 4         259.0          -21.0         0          0                  NaN
#
#    AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 0               NaN             NaN            NaN                  NaN
# 1               NaN             NaN            NaN                  NaN
# 2               NaN             NaN            NaN                  NaN
# 3               NaN             NaN            NaN                  NaN
# 4               NaN             NaN            NaN                  NaN
#
#    WEATHER_DELAY
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 31 columns]

# %%
data.tail()
# Out:
#        YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 19994  2015     12   31            4      B6            688      N657JB
# 19995  2015     12   31            4      B6            745      N828JB
# 19996  2015     12   31            4      B6           1503      N913JB
# 19997  2015     12   31            4      B6            333      N527JB
# 19998  2015     12   31            4      B6            839      N534JB
#
#       ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE      ...        \
# 19994            LAX                 BOS                 2359      ...
# 19995            JFK                 PSE                 2359      ...
# 19996            JFK                 SJU                 2359      ...
# 19997            MCO                 SJU                 2359      ...
# 19998            JFK                 BQN                 2359      ...
#
#        ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 19994         753.0          -26.0         0          0                  NaN
# 19995         430.0          -16.0         0          0                  NaN
# 19996         432.0           -8.0         0          0                  NaN
# 19997         330.0          -10.0         0          0                  NaN
# 19998         442.0            2.0         0          0                  NaN
#
#        AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 19994               NaN             NaN            NaN                  NaN
# 19995               NaN             NaN            NaN                  NaN
# 19996               NaN             NaN            NaN                  NaN
# 19997               NaN             NaN            NaN                  NaN
# 19998               NaN             NaN            NaN                  NaN
#
#        WEATHER_DELAY
# 19994            NaN
# 19995            NaN
# 19996            NaN
# 19997            NaN
# 19998            NaN
#
# [5 rows x 31 columns]

# %%
data
# Out:
#        YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0      2015      1    1            4      AS             98      N407AS
# 1      2015      1    1            4      AA           2336      N3KUAA
# 2      2015      1    1            4      US            840      N171US
# 3      2015      1    1            4      AA            258      N3HYAA
# 4      2015      1    1            4      AS            135      N527AS
# 5      2015      1    1            4      DL            806      N3730B
# 6      2015      1    1            4      NK            612      N635NK
# 7      2015      1    1            4      US           2013      N584UW
# 8      2015      1    1            4      AA           1112      N3LAAA
# 9      2015      1    1            4      DL           1173      N826DN
# 10     2015      1    1            4      DL           2336      N958DN
# 11     2015      1    1            4      AA           1674      N853AA
# 12     2015      1    1            4      DL           1434      N547US
# 13     2015      1    1            4      DL           2324      N3751B
# 14     2015      1    1            4      DL           2440      N651DL
# 15     2015      1    1            4      AS            108      N309AS
# 16     2015      1    1            4      DL           1560      N3743H
# 17     2015      1    1            4      UA           1197      N78448
# 18     2015      1    1            4      AS            122      N413AS
# 19     2015      1    1            4      DL           1670      N806DN
# 20     2015      1    1            4      NK            520      N525NK
# 21     2015      1    1            4      AA            371      N3GXAA
# 22     2015      1    1            4      NK            214      N632NK
# 23     2015      1    1            4      AA            115      N3CTAA
# 24     2015      1    1            4      DL           1450      N671DN
# 25     2015      1    1            4      UA           1545      N76517
# 26     2015      1    1            4      AS            130      N457AS
# 27     2015      1    1            4      NK            597      N528NK
# 28     2015      1    1            4      US            413      N571UW
# 29     2015      1    1            4      AA           2392      N3HRAA
# ...     ...    ...  ...          ...     ...            ...         ...
# 19969  2015     12   31            4      AA           1538      N866AA
# 19970  2015     12   31            4      B6            136      N569JB
# 19971  2015     12   31            4      AS             28      N477AS
# 19972  2015     12   31            4      AS            111      N586AS
# 19973  2015     12   31            4      AS            121      N768AS
# 19974  2015     12   31            4      AS            175      N431AS
# 19975  2015     12   31            4      AS            471      N570AS
# 19976  2015     12   31            4      AS            850      N536AS
# 19977  2015     12   31            4      NK            371      N661NK
# 19978  2015     12   31            4      DL           2224      N332NW
# 19979  2015     12   31            4      F9            710      N209FR
# 19980  2015     12   31            4      F9            682      N701FR
# 19981  2015     12   31            4      F9            566      N925FR
# 19982  2015     12   31            4      F9            300      N949FR
# 19983  2015     12   31            4      UA            516      N17245
# 19984  2015     12   31            4      UA            668      N66848
# 19985  2015     12   31            4      UA            671      N33209
# 19986  2015     12   31            4      UA           1849      N497UA
# 19987  2015     12   31            4      AA           2342      N3DLAA
# 19988  2015     12   31            4      AA            219      N3LYAA
# 19989  2015     12   31            4      B6           1248      N948JB
# 19990  2015     12   31            4      B6             80      N584JB
# 19991  2015     12   31            4      B6            802      N589JB
# 19992  2015     12   31            4      B6             98      N607JB
# 19993  2015     12   31            4      B6             66      N655JB
# 19994  2015     12   31            4      B6            688      N657JB
# 19995  2015     12   31            4      B6            745      N828JB
# 19996  2015     12   31            4      B6           1503      N913JB
# 19997  2015     12   31            4      B6            333      N527JB
# 19998  2015     12   31            4      B6            839      N534JB
#
#       ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE      ...        \
# 0                ANC                 SEA                    5      ...
# 1                LAX                 PBI                   10      ...
# 2                SFO                 CLT                   20      ...
# 3                LAX                 MIA                   20      ...
# 4                SEA                 ANC                   25      ...
# 5                SFO                 MSP                   25      ...
# 6                LAS                 MSP                   25      ...
# 7                LAX                 CLT                   30      ...
# 8                SFO                 DFW                   30      ...
# 9                LAS                 ATL                   30      ...
# 10               DEN                 ATL                   30      ...
# 11               LAS                 MIA                   35      ...
# 12               LAX                 MSP                   35      ...
# 13               SLC                 ATL                   40      ...
# 14               SEA                 MSP                   40      ...
# 15               ANC                 SEA                   45      ...
# 16               ANC                 SEA                   45      ...
# 17               SFO                 IAH                   48      ...
# 18               ANC                 PDX                   50      ...
# 19               PDX                 MSP                   50      ...
# 20               LAS                 MCI                   55      ...
# 21               SEA                 MIA                  100      ...
# 22               LAS                 DFW                  103      ...
# 23               LAX                 MIA                  105      ...
# 24               LAS                 MSP                  105      ...
# 25               LAX                 IAH                  115      ...
# 26               FAI                 SEA                  115      ...
# 27               MSP                 FLL                  115      ...
# 28               LAS                 CLT                  120      ...
# 29               DEN                 MIA                  120      ...
# ...              ...                 ...                  ...      ...
# 19969            LAX                 MIA                 2355      ...
# 19970            PHX                 JFK                 2355      ...
# 19971            SEA                 MSP                 2355      ...
# 19972            LAS                 ANC                 2355      ...
# 19973            SEA                 ANC                 2355      ...
# 19974            LAX                 ANC                 2355      ...
# 19975            LAX                 SEA                 2355      ...
# 19976            KOA                 SEA                 2355      ...
# 19977            FLL                 BQN                 2358      ...
# 19978            PHX                 DTW                 2359      ...
# 19979            DEN                 RSW                 2359      ...
# 19980            DEN                 MCO                 2359      ...
# 19981            DEN                 RDU                 2359      ...
# 19982            DEN                 TPA                 2359      ...
# 19983            SEA                 IAH                 2359      ...
# 19984            LAS                 IAD                 2359      ...
# 19985            PDX                 IAH                 2359      ...
# 19986            LAS                 EWR                 2359      ...
# 19987            DEN                 MIA                 2359      ...
# 19988            LAX                 ORD                 2359      ...
# 19989            LAS                 JFK                 2359      ...
# 19990            RNO                 JFK                 2359      ...
# 19991            SLC                 MCO                 2359      ...
# 19992            DEN                 JFK                 2359      ...
# 19993            ABQ                 JFK                 2359      ...
# 19994            LAX                 BOS                 2359      ...
# 19995            JFK                 PSE                 2359      ...
# 19996            JFK                 SJU                 2359      ...
# 19997            MCO                 SJU                 2359      ...
# 19998            JFK                 BQN                 2359      ...
#
#        ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  CANCELLATION_REASON  \
# 0             408.0          -22.0         0          0                  NaN
# 1             741.0           -9.0         0          0                  NaN
# 2             811.0            5.0         0          0                  NaN
# 3             756.0           -9.0         0          0                  NaN
# 4             259.0          -21.0         0          0                  NaN
# 5             610.0            8.0         0          0                  NaN
# 6             509.0          -17.0         0          0                  NaN
# 7             753.0          -10.0         0          0                  NaN
# 8             532.0          -13.0         0          0                  NaN
# 9             656.0          -15.0         0          0                  NaN
# 10            453.0          -30.0         0          0                  NaN
# 11            753.0          -10.0         0          0                  NaN
# 12            605.0           -4.0         0          0                  NaN
# 13            553.0          -22.0         0          0                  NaN
# 14            557.0            8.0         0          0                  NaN
# 15            455.0          -14.0         0          0                  NaN
# 16            451.0          -24.0         0          0                  NaN
# 17            619.0           -7.0         0          0                  NaN
# 18            507.0          -18.0         0          0                  NaN
# 19            551.0          -12.0         0          0                  NaN
# 20            543.0            6.0         0          0                  NaN
# 21            939.0            1.0         0          0                  NaN
# 22            529.0           -1.0         0          0                  NaN
# 23            839.0          -12.0         0          0                  NaN
# 24            545.0          -23.0         0          0                  NaN
# 25            607.0          -11.0         0          0                  NaN
# 26            545.0           -3.0         0          0                  NaN
# 27            607.0           25.0         0          0                  NaN
# 28            754.0          -31.0         0          0                  NaN
# 29            709.0            2.0         0          0                  NaN
# ...             ...            ...       ...        ...                  ...
# 19969         731.0          -17.0         0          0                  NaN
# 19970         607.0          -15.0         0          0                  NaN
# 19971         535.0           28.0         0          0                  NaN
# 19972         353.0          -62.0         0          0                  NaN
# 19973         224.0          -27.0         0          0                  NaN
# 19974         400.0          -45.0         0          0                  NaN
# 19975         225.0          -19.0         0          0                  NaN
# 19976         712.0          -38.0         0          0                  NaN
# 19977         346.0           28.0         0          0                  NaN
# 19978         512.0          -31.0         0          0                  NaN
# 19979         518.0          -12.0         0          0                  NaN
# 19980         504.0          -21.0         0          0                  NaN
# 19981         446.0          -18.0         0          0                  NaN
# 19982         509.0           -9.0         0          0                  NaN
# 19983         600.0           -6.0         0          0                  NaN
# 19984         652.0          -29.0         0          0                  NaN
# 19985         545.0          -19.0         0          0                  NaN
# 19986         718.0          -24.0         0          0                  NaN
# 19987         525.0          -18.0         0          0                  NaN
# 19988         544.0          -19.0         0          0                  NaN
# 19989        1020.0          159.0         0          0                  NaN
# 19990         744.0          -21.0         0          0                  NaN
# 19991         625.0           17.0         0          0                  NaN
# 19992         519.0          -11.0         0          0                  NaN
# 19993         549.0            3.0         0          0                  NaN
# 19994         753.0          -26.0         0          0                  NaN
# 19995         430.0          -16.0         0          0                  NaN
# 19996         432.0           -8.0         0          0                  NaN
# 19997         330.0          -10.0         0          0                  NaN
# 19998         442.0            2.0         0          0                  NaN
#
#        AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 0                   NaN             NaN            NaN                  NaN
# 1                   NaN             NaN            NaN                  NaN
# 2                   NaN             NaN            NaN                  NaN
# 3                   NaN             NaN            NaN                  NaN
# 4                   NaN             NaN            NaN                  NaN
# 5                   NaN             NaN            NaN                  NaN
# 6                   NaN             NaN            NaN                  NaN
# 7                   NaN             NaN            NaN                  NaN
# 8                   NaN             NaN            NaN                  NaN
# 9                   NaN             NaN            NaN                  NaN
# 10                  NaN             NaN            NaN                  NaN
# 11                  NaN             NaN            NaN                  NaN
# 12                  NaN             NaN            NaN                  NaN
# 13                  NaN             NaN            NaN                  NaN
# 14                  NaN             NaN            NaN                  NaN
# 15                  NaN             NaN            NaN                  NaN
# 16                  NaN             NaN            NaN                  NaN
# 17                  NaN             NaN            NaN                  NaN
# 18                  NaN             NaN            NaN                  NaN
# 19                  NaN             NaN            NaN                  NaN
# 20                  NaN             NaN            NaN                  NaN
# 21                  NaN             NaN            NaN                  NaN
# 22                  NaN             NaN            NaN                  NaN
# 23                  NaN             NaN            NaN                  NaN
# 24                  NaN             NaN            NaN                  NaN
# 25                  NaN             NaN            NaN                  NaN
# 26                  NaN             NaN            NaN                  NaN
# 27                 25.0             0.0            0.0                  0.0
# 28                  NaN             NaN            NaN                  NaN
# 29                  NaN             NaN            NaN                  NaN
# ...                 ...             ...            ...                  ...
# 19969               NaN             NaN            NaN                  NaN
# 19970               NaN             NaN            NaN                  NaN
# 19971              12.0             0.0           16.0                  0.0
# 19972               NaN             NaN            NaN                  NaN
# 19973               NaN             NaN            NaN                  NaN
# 19974               NaN             NaN            NaN                  NaN
# 19975               NaN             NaN            NaN                  NaN
# 19976               NaN             NaN            NaN                  NaN
# 19977              15.0             0.0           13.0                  0.0
# 19978               NaN             NaN            NaN                  NaN
# 19979               NaN             NaN            NaN                  NaN
# 19980               NaN             NaN            NaN                  NaN
# 19981               NaN             NaN            NaN                  NaN
# 19982               NaN             NaN            NaN                  NaN
# 19983               NaN             NaN            NaN                  NaN
# 19984               NaN             NaN            NaN                  NaN
# 19985               NaN             NaN            NaN                  NaN
# 19986               NaN             NaN            NaN                  NaN
# 19987               NaN             NaN            NaN                  NaN
# 19988               NaN             NaN            NaN                  NaN
# 19989               0.0             0.0          159.0                  0.0
# 19990               NaN             NaN            NaN                  NaN
# 19991               1.0             0.0           16.0                  0.0
# 19992               NaN             NaN            NaN                  NaN
# 19993               NaN             NaN            NaN                  NaN
# 19994               NaN             NaN            NaN                  NaN
# 19995               NaN             NaN            NaN                  NaN
# 19996               NaN             NaN            NaN                  NaN
# 19997               NaN             NaN            NaN                  NaN
# 19998               NaN             NaN            NaN                  NaN
#
#        WEATHER_DELAY
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19               NaN
# 20               NaN
# 21               NaN
# 22               NaN
# 23               NaN
# 24               NaN
# 25               NaN
# 26               NaN
# 27               0.0
# 28               NaN
# 29               NaN
# ...              ...
# 19969            NaN
# 19970            NaN
# 19971            0.0
# 19972            NaN
# 19973            NaN
# 19974            NaN
# 19975            NaN
# 19976            NaN
# 19977            0.0
# 19978            NaN
# 19979            NaN
# 19980            NaN
# 19981            NaN
# 19982            NaN
# 19983            NaN
# 19984            NaN
# 19985            NaN
# 19986            NaN
# 19987            NaN
# 19988            NaN
# 19989            0.0
# 19990            NaN
# 19991            0.0
# 19992            NaN
# 19993            NaN
# 19994            NaN
# 19995            NaN
# 19996            NaN
# 19997            NaN
# 19998            NaN
#
# [19999 rows x 31 columns]

# %% [markdown]
# From the above table it is clear that data is not properly organised and date is given seperated and many columns have unnecessary data not useful for visualization for which it is required that we clean the data and take only those columns which is of our use.

# %%
airport.isnull().sum()
# Out:
# IATA_CODE    0
# AIRPORT      0
# CITY         0
# STATE        0
# COUNTRY      0
# LATITUDE     3
# LONGITUDE    3
# dtype: int64

# %%
airport = airport.dropna(subset = ['LATITUDE','LONGITUDE'])

# %%
airport.isnull().sum()
# Out:
# IATA_CODE    0
# AIRPORT      0
# CITY         0
# STATE        0
# COUNTRY      0
# LATITUDE     0
# LONGITUDE    0
# dtype: int64

# %%
airport.head(10)
# Out:
#   IATA_CODE                              AIRPORT           CITY STATE COUNTRY  \
# 0       ABE  Lehigh Valley International Airport      Allentown    PA     USA
# 1       ABI             Abilene Regional Airport        Abilene    TX     USA
# 2       ABQ    Albuquerque International Sunport    Albuquerque    NM     USA
# 3       ABR            Aberdeen Regional Airport       Aberdeen    SD     USA
# 4       ABY   Southwest Georgia Regional Airport         Albany    GA     USA
# 5       ACK           Nantucket Memorial Airport      Nantucket    MA     USA
# 6       ACT                Waco Regional Airport           Waco    TX     USA
# 7       ACV                       Arcata Airport  Arcata/Eureka    CA     USA
# 8       ACY  Atlantic City International Airport  Atlantic City    NJ     USA
# 9       ADK                         Adak Airport           Adak    AK     USA
#
#    LATITUDE  LONGITUDE
# 0  40.65236  -75.44040
# 1  32.41132  -99.68190
# 2  35.04022 -106.60919
# 3  45.44906  -98.42183
# 4  31.53552  -84.19447
# 5  41.25305  -70.06018
# 6  31.61129  -97.23052
# 7  40.97812 -124.10862
# 8  39.45758  -74.57717
# 9  51.87796 -176.64603

# %%
airlines
# Out:
#    IATA_CODE                       AIRLINE
# 0         UA         United Air Lines Inc.
# 1         AA        American Airlines Inc.
# 2         US               US Airways Inc.
# 3         F9        Frontier Airlines Inc.
# 4         B6               JetBlue Airways
# 5         OO         Skywest Airlines Inc.
# 6         AS          Alaska Airlines Inc.
# 7         NK              Spirit Air Lines
# 8         WN        Southwest Airlines Co.
# 9         DL          Delta Air Lines Inc.
# 10        EV   Atlantic Southeast Airlines
# 11        HA        Hawaiian Airlines Inc.
# 12        MQ  American Eagle Airlines Inc.
# 13        VX                Virgin America

# %%
Data_NULL = data.isnull().sum()*100/data.shape[0]
Data_NULL
# Out:
# YEAR                    0.000000
# MONTH                   0.000000
# DAY                     0.000000
# DAY_OF_WEEK             0.000000
# AIRLINE                 0.000000
# FLIGHT_NUMBER           0.000000
# TAIL_NUMBER             0.115006
# ORIGIN_AIRPORT          0.000000
# DESTINATION_AIRPORT     0.000000
# SCHEDULED_DEPARTURE     0.000000
# DEPARTURE_TIME          2.045102
# DEPARTURE_DELAY         2.045102
# TAXI_OUT                2.050103
# WHEELS_OFF              2.050103
# SCHEDULED_TIME          0.000000
# ELAPSED_TIME            2.200110
# AIR_TIME                2.200110
# DISTANCE                0.000000
# WHEELS_ON               2.110106
# TAXI_IN                 2.110106
# SCHEDULED_ARRIVAL       0.000000
# ARRIVAL_TIME            2.110106
# ARRIVAL_DELAY           2.200110
# DIVERTED                0.000000
# CANCELLED               0.000000
# CANCELLATION_REASON    97.924896
# AIR_SYSTEM_DELAY       83.334167
# SECURITY_DELAY         83.334167
# AIRLINE_DELAY          83.334167
# LATE_AIRCRAFT_DELAY    83.334167
# WEATHER_DELAY          83.334167
# dtype: float64

# %% [markdown]
# We can see that 96% of the values in Cancellation reason column are null for which it is of less use while predicting Delays. Some other columns include 78.2% in Air System Delay, Security Delay, Airline Delay, Weather Delay etc. So I am going to create two Dataset which is having no null values one is by removing all the null values irrespective of different types of Delays and other I am going to take the data set with respect to different types of delays. The first Dataset is named as Flights and the other one is named as Flight_Delays.

# %%
# Dropping of subset of null values
data1 = data.dropna(subset = ["TAIL_NUMBER",'DEPARTURE_TIME','DEPARTURE_DELAY','TAXI_OUT','WHEELS_OFF','SCHEDULED_TIME',
             'ELAPSED_TIME','AIR_TIME','WHEELS_ON','TAXI_IN','ARRIVAL_TIME','ARRIVAL_DELAY'])

# %%
data1.shape
# Out:
# (19559, 31)

# %%
data1.isnull().sum()
# Out:
# YEAR                       0
# MONTH                      0
# DAY                        0
# DAY_OF_WEEK                0
# AIRLINE                    0
# FLIGHT_NUMBER              0
# TAIL_NUMBER                0
# ORIGIN_AIRPORT             0
# DESTINATION_AIRPORT        0
# SCHEDULED_DEPARTURE        0
# DEPARTURE_TIME             0
# DEPARTURE_DELAY            0
# TAXI_OUT                   0
# WHEELS_OFF                 0
# SCHEDULED_TIME             0
# ELAPSED_TIME               0
# AIR_TIME                   0
# DISTANCE                   0
# WHEELS_ON                  0
# TAXI_IN                    0
# SCHEDULED_ARRIVAL          0
# ARRIVAL_TIME               0
# ARRIVAL_DELAY              0
# DIVERTED                   0
# CANCELLED                  0
# CANCELLATION_REASON    19559
# AIR_SYSTEM_DELAY       16226
# SECURITY_DELAY         16226
# AIRLINE_DELAY          16226
# LATE_AIRCRAFT_DELAY    16226
# WEATHER_DELAY          16226
# dtype: int64

# %%
# Creting Dataset w.r.t different Types of Delays
data11 = data1.dropna(subset = ['AIR_SYSTEM_DELAY','SECURITY_DELAY','AIRLINE_DELAY','LATE_AIRCRAFT_DELAY','WEATHER_DELAY'])
data11 = data11.drop(['YEAR','MONTH','DAY','DAY_OF_WEEK','TAIL_NUMBER','SCHEDULED_DEPARTURE','DEPARTURE_TIME','SCHEDULED_TIME',
                     'SCHEDULED_ARRIVAL','ARRIVAL_TIME','DIVERTED','CANCELLED','CANCELLATION_REASON','FLIGHT_NUMBER','WHEELS_OFF',
                     'WHEELS_ON','AIR_TIME'],axis = 1)

# %%
data11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3333 entries, 27 to 19991
# Data columns (total 14 columns):
# AIRLINE                3333 non-null object
# ORIGIN_AIRPORT         3333 non-null object
# DESTINATION_AIRPORT    3333 non-null object
# DEPARTURE_DELAY        3333 non-null float64
# TAXI_OUT               3333 non-null float64
# ELAPSED_TIME           3333 non-null float64
# DISTANCE               3333 non-null int64
# TAXI_IN                3333 non-null float64
# ARRIVAL_DELAY          3333 non-null float64
# AIR_SYSTEM_DELAY       3333 non-null float64
# SECURITY_DELAY         3333 non-null float64
# AIRLINE_DELAY          3333 non-null float64
# LATE_AIRCRAFT_DELAY    3333 non-null float64
# WEATHER_DELAY          3333 non-null float64
# dtypes: float64(10), int64(1), object(3)
# memory usage: 390.6+ KB

# %%
# The other Dataset
Flight_Delays = data11

# %%
# Creating Dataset by removing null values by not focussing fully on different types of Delays
data2 = data1.drop(['CANCELLATION_REASON','AIR_SYSTEM_DELAY','SECURITY_DELAY','AIRLINE_DELAY',
                    'LATE_AIRCRAFT_DELAY','WEATHER_DELAY'],axis = 1)

# %%
data2.isnull().sum()
# Out:
# YEAR                   0
# MONTH                  0
# DAY                    0
# DAY_OF_WEEK            0
# AIRLINE                0
# FLIGHT_NUMBER          0
# TAIL_NUMBER            0
# ORIGIN_AIRPORT         0
# DESTINATION_AIRPORT    0
# SCHEDULED_DEPARTURE    0
# DEPARTURE_TIME         0
# DEPARTURE_DELAY        0
# TAXI_OUT               0
# WHEELS_OFF             0
# SCHEDULED_TIME         0
# ELAPSED_TIME           0
# AIR_TIME               0
# DISTANCE               0
# WHEELS_ON              0
# TAXI_IN                0
# SCHEDULED_ARRIVAL      0
# ARRIVAL_TIME           0
# ARRIVAL_DELAY          0
# DIVERTED               0
# CANCELLED              0
# dtype: int64

# %%
data2.shape
# Out:
# (19559, 25)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19559 entries, 0 to 19998
# Data columns (total 25 columns):
# YEAR                   19559 non-null int64
# MONTH                  19559 non-null int64
# DAY                    19559 non-null int64
# DAY_OF_WEEK            19559 non-null int64
# AIRLINE                19559 non-null object
# FLIGHT_NUMBER          19559 non-null int64
# TAIL_NUMBER            19559 non-null object
# ORIGIN_AIRPORT         19559 non-null object
# DESTINATION_AIRPORT    19559 non-null object
# SCHEDULED_DEPARTURE    19559 non-null int64
# DEPARTURE_TIME         19559 non-null float64
# DEPARTURE_DELAY        19559 non-null float64
# TAXI_OUT               19559 non-null float64
# WHEELS_OFF             19559 non-null float64
# SCHEDULED_TIME         19559 non-null int64
# ELAPSED_TIME           19559 non-null float64
# AIR_TIME               19559 non-null float64
# DISTANCE               19559 non-null int64
# WHEELS_ON              19559 non-null float64
# TAXI_IN                19559 non-null float64
# SCHEDULED_ARRIVAL      19559 non-null int64
# ARRIVAL_TIME           19559 non-null float64
# ARRIVAL_DELAY          19559 non-null float64
# DIVERTED               19559 non-null int64
# CANCELLED              19559 non-null int64
# dtypes: float64(10), int64(11), object(4)
# memory usage: 3.9+ MB

# %%
data2.DEPARTURE_TIME.isnull().sum()
# Out:
# 0

# %%
data2.DEPARTURE_TIME.dtype
# Out:
# dtype('float64')

# %%
data2.DEPARTURE_TIME
# Out:
# 0        2354.0
# 1           2.0
# 2          18.0
# 3          15.0
# 4          24.0
# 5          20.0
# 6          19.0
# 7          44.0
# 8          19.0
# 9          33.0
# 10         24.0
# 11         27.0
# 12         35.0
# 13         34.0
# 14         39.0
# 15         41.0
# 16         31.0
# 17         42.0
# 18         46.0
# 19         45.0
# 20        120.0
# 21         52.0
# 22        102.0
# 23        103.0
# 24        102.0
# 25        112.0
# 26        107.0
# 27        127.0
# 28        110.0
# 29        141.0
#           ...
# 19969    2357.0
# 19970    2357.0
# 19971      11.0
# 19972    2340.0
# 19973    2355.0
# 19974    2350.0
# 19975    2353.0
# 19976    2352.0
# 19977      11.0
# 19978    2352.0
# 19979    2351.0
# 19980    2354.0
# 19981    2356.0
# 19982       5.0
# 19983       1.0
# 19984    2356.0
# 19985    2352.0
# 19986    2357.0
# 19987    2351.0
# 19988    2358.0
# 19989     238.0
# 19990    2359.0
# 19991      15.0
# 19992       6.0
# 19993      15.0
# 19994    2355.0
# 19995    2355.0
# 19996    2350.0
# 19997    2353.0
# 19998      14.0
# Name: DEPARTURE_TIME, Length: 19559, dtype: float64

# %% [markdown]
# The departure time above is not very much informative so we are going to change it in the datetime format so that we get a better idea of the time.

# %%
# Creating a function to change the way of representation of time in the column
def Format_Hourmin(hours):
        if hours == 2400:
            hours = 0
        else:
            hours = "{0:04d}".format(int(hours))
            Hourmin = datetime.time(int(hours[0:2]), int(hours[2:4]))
            return Hourmin

# %%
data2['Actual_Departure'] = data1['DEPARTURE_TIME'].apply(Format_Hourmin)
data2['Actual_Departure']
# Out:
# 0        23:54:00
# 1        00:02:00
# 2        00:18:00
# 3        00:15:00
# 4        00:24:00
# 5        00:20:00
# 6        00:19:00
# 7        00:44:00
# 8        00:19:00
# 9        00:33:00
# 10       00:24:00
# 11       00:27:00
# 12       00:35:00
# 13       00:34:00
# 14       00:39:00
# 15       00:41:00
# 16       00:31:00
# 17       00:42:00
# 18       00:46:00
# 19       00:45:00
# 20       01:20:00
# 21       00:52:00
# 22       01:02:00
# 23       01:03:00
# 24       01:02:00
# 25       01:12:00
# 26       01:07:00
# 27       01:27:00
# 28       01:10:00
# 29       01:41:00
#            ...
# 19969    23:57:00
# 19970    23:57:00
# 19971    00:11:00
# 19972    23:40:00
# 19973    23:55:00
# 19974    23:50:00
# 19975    23:53:00
# 19976    23:52:00
# 19977    00:11:00
# 19978    23:52:00
# 19979    23:51:00
# 19980    23:54:00
# 19981    23:56:00
# 19982    00:05:00
# 19983    00:01:00
# 19984    23:56:00
# 19985    23:52:00
# 19986    23:57:00
# 19987    23:51:00
# 19988    23:58:00
# 19989    02:38:00
# 19990    23:59:00
# 19991    00:15:00
# 19992    00:06:00
# 19993    00:15:00
# 19994    23:55:00
# 19995    23:55:00
# 19996    23:50:00
# 19997    23:53:00
# 19998    00:14:00
# Name: Actual_Departure, Length: 19559, dtype: object

# %%
data2.columns

# %%
# Creating Date in the Datetime format
data2['Date'] = pd.to_datetime(data2[['YEAR','MONTH','DAY']])
data2.Date

# %%
data2['Day'] = data2['Date'].dt.weekday_name

# %%
# Applying the function to required variables in the dataset
data2['Actual_Departure'] =data1['DEPARTURE_TIME'].apply(Format_Hourmin)
data2['Scheduled_Arrival'] =data1['SCHEDULED_ARRIVAL'].apply(Format_Hourmin)
data2['Scheduled_Departure'] =data1['SCHEDULED_DEPARTURE'].apply(Format_Hourmin)
data2['Actual_Arrival'] =data1['ARRIVAL_TIME'].apply(Format_Hourmin)

# %% [markdown]
# # Merging of  3 data sets

# %% [markdown]
# Since there are three dataset it is required to merge all the three data set so that we can use it during the visualization in a proper way.

# %%
# Merging on AIRLINE and IATA_CODE
data2 = data2.merge(airlines, left_on='AIRLINE', right_on='IATA_CODE', how='inner')

# %%
data2 = data2.drop(['AIRLINE_x','IATA_CODE'], axis=1)

# %%
data2 = data2.rename(columns={"AIRLINE_y":"AIRLINE"})

# %%
data2 = data2.merge(airport, left_on='ORIGIN_AIRPORT', right_on='IATA_CODE', how='inner')
data2 = data2.merge(airport, left_on='DESTINATION_AIRPORT', right_on='IATA_CODE', how='inner')

# %%
data2.columns

# %%
data2 = data2.drop(['LATITUDE_x', 'LONGITUDE_x',
       'STATE_y', 'COUNTRY_y', 'LATITUDE_y', 'LONGITUDE_y','STATE_x', 'COUNTRY_x'], axis=1)

# %%
data2 = data2.rename(columns={'IATA_CODE_x':'Org_Airport_Code','AIRPORT_x':'Org_Airport_Name','CITY_x':'Origin_city',
                             'IATA_CODE_y':'Dest_Airport_Code','AIRPORT_y':'Dest_Airport_Name','CITY_y':'Destination_city'})

# %%
data2

# %%
# we are taking the required data into Account for visualization and the Analysis
ReqdData = pd.DataFrame(data2[['AIRLINE','Org_Airport_Name','Origin_city',
                               'Dest_Airport_Name','Destination_city','ORIGIN_AIRPORT',
                               'DESTINATION_AIRPORT','DISTANCE','Actual_Departure','Date','Day',
                               'Scheduled_Departure','DEPARTURE_DELAY','Actual_Arrival','Scheduled_Arrival','ARRIVAL_DELAY',
                              'SCHEDULED_TIME','ELAPSED_TIME','AIR_TIME','TAXI_IN','TAXI_OUT','DIVERTED',]])

# %%
data2.DEPARTURE_TIME.dtype

# %%
ReqdData = ReqdData.dropna(subset = ['Actual_Departure','Actual_Arrival'])

# %%
ReqdData.info()

# %%
# Cleaned Dataset for visualization and Analysis
Flights = ReqdData
Flights

# %%
plt.figure(figsize=(10, 10))
axis = sns.countplot(x=Flights['Origin_city'], data = Flights,
              order=Flights['Origin_city'].value_counts().iloc[:20].index)
axis.set_xticklabels(axis.get_xticklabels(), rotation=90, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# # The Figure shows that Atlanta has the highest count of flight from origin city

# %%
plt.figure(figsize=(10, 10))
axis = sns.countplot(x=Flights['Org_Airport_Name'], data = Flights,
              order=Flights['Org_Airport_Name'].value_counts().iloc[:20].index)
axis.set_xticklabels(axis.get_xticklabels(), rotation=90, ha="right")
plt.tight_layout()
plt.show()

# %%
axis = plt.subplots(figsize=(10,14))
Name = Flights["AIRLINE"].unique()
size = Flights["AIRLINE"].value_counts()
plt.pie(size,labels=Name,autopct='%5.0f%%')
plt.show()

# %%
axis = plt.subplots(figsize=(10,14))
sns.despine(bottom=True, left=True)
# Observations with Scatter Plot
sns.stripplot(x="ARRIVAL_DELAY", y="AIRLINE",
              data = Flights, dodge=True, jitter=True
            )
plt.show()

# %% [markdown]
# American Airlines Inc has the highest Arrival Delay.

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1569936847474' style='position: relative'><noscript><a href='#'><img alt=' '
# src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;9B&#47;9BD44NRJ9&#47;1_rss.png' style='border: none'
# /></a></noscript><object class='tableauViz'
# style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F'
# /> <param name='embed_code_version' value='3' /> <param name='path' value='shared&#47;9BD44NRJ9'
# /> <param name='toolbar' value='yes'
# /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;9B&#47;9BD44NRJ9&#47;1.png'
# /> <param name='animate_transition' value='yes'
# /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes'
# /><param name='display_overlay' value='yes' /><param name='display_count' value='yes'
# /><param name='filter' value='publish=yes' /></object></div>
# <script type='text/javascript'>
# var divElement = document.getElementById('viz1569936847474');
# var vizElement = divElement.getElementsByTagName('object')[0];
# vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';
# var scriptElement = document.createElement('script');
# scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';
# vizElement.parentNode.insertBefore(scriptElement, vizElement);
# </script>

# %% [markdown]
# # Tableau Visualization to give more clear Insight and Inferences

# %%
# Plot to show the Taxi In and Taxi Out Time
axis = plt.subplots(figsize=(10,14))
sns.set_color_codes("pastel")
sns.set_context("notebook", font_scale=1.5)
axis = sns.barplot(x="TAXI_OUT", y="AIRLINE", data=Flights, color="g")
axis = sns.barplot(x="TAXI_IN", y="AIRLINE", data=Flights, color="r")
axis.set(xlabel="TAXI_TIME (TAXI_OUT: green, TAXI_IN: blue)")

# %%
axis = plt.subplots(figsize=(20,14))
sns.heatmap(Flights.corr(),annot = True)
plt.show()

# %% [markdown]
# # Very High Correlation Between Arrival Delay and Departure Delay

# %% [markdown]
# It shows that maximum of the Arrival Delays are due to the Departure Delays but some flights has still arrived on time even after departed late from the Origin Airport. Now we need to check why departure Delay is happening in the origin Airport Which may be due to security Delays, Air System Delays etc.

# %%
# %%html
# <div class='tableauPlaceholder' id='viz1569938215526' style='position: relative'><noscript><a href='#'><img alt=' '
# src='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;PH&#47;PHNKQPSZG&#47;1_rss.png' style='border: none'
# /></a></noscript><object class='tableauViz'  style='display:none;'><param name='host_url' value='https%3A%2F%2Fpublic.tableau.com%2F'
# /> <param name='embed_code_version' value='3'
# /> <param name='path' value='shared&#47;PHNKQPSZG'
# /> <param name='toolbar' value='yes' /><param name='static_image' value='https:&#47;&#47;public.tableau.com&#47;static&#47;images&#47;PH&#47;PHNKQPSZG&#47;1.png'
# /> <param name='animate_transition' value='yes' /><param name='display_static_image' value='yes' /><param name='display_spinner' value='yes'
# /><param name='display_overlay' value='yes'
# /><param name='display_count' value='yes' /></object></div>
# <script type='text/javascript'>
# var divElement = document.getElementById('viz1569938215526');
# var vizElement = divElement.getElementsByTagName('object')[0];
# vizElement.style.width='100%';vizElement.style.height=(divElement.offsetWidth*0.75)+'px';
# var scriptElement = document.createElement('script');
# scriptElement.src = 'https://public.tableau.com/javascripts/api/viz_v1.js';
# vizElement.parentNode.insertBefore(scriptElement, vizElement);
# </script>

# %% [markdown]
# # Tableau Visualization to give more clear Insight and Inferences

# %% [markdown]
# # Prediction

# %%
Flights.head()

# %%
# Dropping unncecssary columns before prediction
Flights1 = Flights.drop(['Org_Airport_Name','Origin_city','Dest_Airport_Name','Destination_city'],axis = 1)

# %%
Flights1.columns

# %%
# To check the Distribution of Air Time
sns.distplot(Flights1['AIR_TIME'])
plt.show()

# %%
# To check the Distribution of Elapsed Time
sns.distplot(Flights1['ELAPSED_TIME'])
plt.show()

# %%
# To check the Distribution of Taxi IN
sns.distplot(Flights1['TAXI_IN'])
plt.show()

# %%
# To check the Distribution of Taxi out
sns.distplot(Flights1['TAXI_OUT'])
plt.show()

# %%
# importing Various regression algorithms 
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import Lasso,LinearRegression,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,BaggingRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
Las = Lasso()
LinR = LinearRegression()
Rid = Ridge()
Rfc = RandomForestRegressor(random_state=2)
Dtc = DecisionTreeRegressor(random_state = 2)
Boost_Lin = AdaBoostRegressor(base_estimator=LinR,random_state=2)
Boost_las = AdaBoostRegressor(base_estimator=Las,random_state=2)
Boost_rid = AdaBoostRegressor(base_estimator=Rid,random_state=2)
Bg_Lin = BaggingRegressor(base_estimator=LinR,random_state=2)
Bg_las = BaggingRegressor(base_estimator=Las,random_state=2)
Bg_rid = BaggingRegressor(base_estimator=Rid,random_state=2)

# %%
le = LabelEncoder()

# %%
# Label encoding features to change categorical variables into numerical one
Flights1['AIRLINE']= le.fit_transform(Flights1['AIRLINE'])
Flights1['ORIGIN_AIRPORT'] = le.fit_transform(Flights1['ORIGIN_AIRPORT'])
Flights1['DESTINATION_AIRPORT'] = le.fit_transform(Flights1['DESTINATION_AIRPORT'])
Flights1['Day'] = le.fit_transform(Flights1['Day'])

# %%
Flights1 = Flights1.drop(['Scheduled_Departure','Scheduled_Arrival','Actual_Arrival','Date','Actual_Departure'], axis = 1)

# %%
Flights1.info()

# %%
X = Flights1.drop('ARRIVAL_DELAY',axis = 1)
X.shape

# %%
y = Flights1['ARRIVAL_DELAY']
y.head()

# %%
# Splitting into train and test data set
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state = 2)

# %%
sc1=StandardScaler()
X_train_sc=sc1.fit_transform(X_train)
X_test_sc=sc1.transform(X_test)

# %% [markdown]
# # Model fitting and results

# %%
for model, name in zip([Las,LinR,Rid,Dtc,Rfc,Boost_Lin,Boost_las,Boost_rid,Bg_Lin,Bg_las,Bg_rid], 
     ['Lasso','Linear Regression','Ridge','Random forest Regressor','Decision Tree Regressor','Boosted Linear',
      'Boosted Lasso','Boosted Ridge','Bagged Linear','Bagged Lasso','Bagged Ridge']):
    model1 = model.fit(X_train_sc,y_train)
    Y_predict=model1.predict(X_test_sc)
    print(name)
    print('Mean Absolute Error:', mean_absolute_error(y_test, Y_predict))  
    print('Mean Squared Error:', mean_squared_error(y_test, Y_predict))  
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, Y_predict)))
    print('R2 : ',r2_score(y_test, Y_predict))
    print()

# %% [markdown]
# # Model Analysis

# %%
for model, name in zip([Las,LinR,Rid,Dtc,Rfc,Boost_Lin,Boost_las,Boost_rid,Bg_Lin,Bg_las,Bg_rid], 
     ['Lasso','Linear Regression','Ridge','Random forest Regressor','Decision Tree Regressor','Boosted Linear',
      'Boosted Lasso','Boosted Ridge','Bagged Linear','Bagged Lasso','Bagged Ridge']):
    model1 = model.fit(X_train_sc,y_train)
    Y_predict=model1.predict(X_test_sc)
    print(name)
    plt.scatter(y_test, Y_predict)
    plt.title("Model Analysis")
    plt.xlabel("Truth")
    plt.ylabel("Prediction")
    plt.show()

# %% [markdown]
# # When Flight_Delays is taken, where I took all the different Delays into Concern.

# %% [markdown]
# I removed the null values present in all the different types of Delays and proceeded with prediction of the Arrival Delays.

# %%
axis = plt.subplots(figsize=(10,14))
Name = Flight_Delays["AIRLINE"].unique()
size = Flight_Delays["AIRLINE"].value_counts()
plt.pie(size,labels=Name,autopct='%5.0f%%')
plt.show()

# %%
Flight_Delays

# %%
Flight_Delays['ORIGIN_AIRPORT'] = Flight_Delays['ORIGIN_AIRPORT'].astype(str)
Flight_Delays['DESTINATION_AIRPORT'] = Flight_Delays['DESTINATION_AIRPORT'].astype(str)

# %%
Flight_Delays['AIRLINE']= le.fit_transform(Flight_Delays['AIRLINE'])
Flight_Delays['ORIGIN_AIRPORT'] = le.fit_transform(Flight_Delays['ORIGIN_AIRPORT'])
Flight_Delays['DESTINATION_AIRPORT'] = le.fit_transform(Flight_Delays['DESTINATION_AIRPORT'])

# %%
X = Flight_Delays.drop('ARRIVAL_DELAY',axis = 1)
X.shape
y = Flight_Delays['ARRIVAL_DELAY']
y.head()

# %%
# Splitting the Data into Training and Testing set
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state = 2)

# %%
# Scalling of the Data
sc1=StandardScaler()
X_train_sc=sc1.fit_transform(X_train)
X_test_sc=sc1.transform(X_test)

# %% [markdown]
# # Model fitting and results

# %%
for model, name in zip([Las,LinR,Rid,Dtc,Rfc,Boost_Lin,Boost_las,Boost_rid,Bg_Lin,Bg_las,Bg_rid], 
     ['Lasso','Linear Regression','Ridge','Random forest Regressor','Decision Tree Regressor','Boosted Linear',
      'Boosted Lasso','Boosted Ridge','Bagged Linear','Bagged Lasso','Bagged Ridge']):
    model1 = model.fit(X_train_sc,y_train)
    Y_predict=model1.predict(X_test_sc)
    print(name)
    print('Mean Absolute Error:', mean_absolute_error(y_test, Y_predict))  
    print('Mean Squared Error:', mean_squared_error(y_test, Y_predict))  
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test, Y_predict)))
    print('R2 : ',r2_score(y_test, Y_predict))
    print()

# %% [markdown]
# # Model Analysis

# %%
for model, name in zip([Las,LinR,Rid,Dtc,Rfc,Boost_Lin,Boost_las,Boost_rid,Bg_Lin,Bg_las,Bg_rid], 
     ['Lasso','Linear Regression','Ridge','Random forest Regressor','Decision Tree Regressor','Boosted Linear',
      'Boosted Lasso','Boosted Ridge','Bagged Linear','Bagged Lasso','Bagged Ridge']):
    model1 = model.fit(X_train_sc,y_train)
    Y_predict=model1.predict(X_test_sc)
    print(name)
    plt.scatter(y_test, Y_predict)
    plt.title("Model Analysis")
    plt.xlabel("Truth")
    plt.ylabel("Prediction")
    plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# We can see that maximum arrival Delays are dependent on the Departure Delays of the Airport. The first part is dealt with cleaning and exploration of the data set to get more insights and the second part dealt with the sitting of the model to predict the delays. For exploratory Analysis I used visualization tools like tableau and seaborn as well as matplotlib. The Second part dealt with the model fitting and predicting the Arrival delays of the airlines.
#
# We can see that departure delay is the main problem which is creating Delay in the aviation industry. Departure Delays can be caused due Security Delay, Airline System Delays, Airlines Delay etc. The Delays affect the revenue of the company to a great extent so the delays has to be reduced as much as possible so as to increase the profitability in the Airline Industry. Customer Satisfaction will also be greatly enhanced if the delays can be brought down as low as possible.
